# %%
import time

def print_numbers():
    for i in range(5):
        time.sleep(1)
        print(i)

def print_alphabets():
    for i in ['a', 'b', 'c', 'd', 'e']:
        time.sleep(1)
        print(i)

start_time = time.time()
print_numbers()
print_alphabets()
end_time = time.time()
total_time = end_time - start_time
print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# 0
# 1
# 2
# 3
# 4
# a
# b
# c
# d
# e
# Total execution time: 10.01 seconds

# %% [markdown]
# ⛔ t1.join()
# This tells the main thread (your Python script) to pause and wait until Thread-1 is done.
#
# It doesn’t stop Thread-2. t2 can continue running in parallel.
#
# ⛔ t2.join()
# After Thread-1 is done, this tells the main thread to now wait for Thread-2 to finish (if it's not done already).

# %%
import threading
import time

def print_numbers():
    for i in range(5):
        time.sleep(1)
        print(i)

def print_alphabets():
    for i in ['a', 'b', 'c', 'd', 'e']:
        time.sleep(1)
        print(i)
            
        
# Create threads
thread1 = threading.Thread(target=print_numbers, name="Thread-1")
thread2 = threading.Thread(target=print_alphabets, name="Thread-2")

start_time = time.time()

# Start threads
thread1.start()
thread2.start()

# Wait for threads to finish
thread1.join()
thread2.join()


end_time = time.time()
total_time = end_time - start_time

print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# 0a
#
# b
# 1
# c
# 2
# d
# 3
# e4
#
# Total execution time: 5.02 seconds

# %% [markdown]
# | Thread Type           | Description                                                                     |
# | --------------------- | ------------------------------------------------------------------------------- |
# | **Daemon Thread**     | Background thread that is killed when the main thread ends. Optional task.      |
# | **Non-Daemon Thread** | Normal thread that keeps running and **blocks** program exit until it finishes. |

# %% [markdown]
# | Feature / Aspect        | **CPU-bound Tasks**                                                 | **I/O-bound Tasks**                                 |
# | ----------------------- | ------------------------------------------------------------------- | --------------------------------------------------- |
# | **Definition**          | Tasks that use CPU heavily for computation                          | Tasks that spend time waiting for input/output      |
# | **Main Bottleneck**     | CPU (processing power)                                              | I/O (disk, network, DB, etc.)                       |
# | **Examples**            | - Complex math<br>- Image/video processing<br>- Sorting large lists | - File read/write<br>- Web scraping<br>- DB queries |
# | **GIL Impact**          | Major limitation in Python with threads                             | Less impact, threads can still switch on wait       |
# | **Best Tool**           | ✅ `multiprocessing` or `ProcessPoolExecutor`                        | ✅ `threading` or `ThreadPoolExecutor`               |
# | **Runs in Parallel?**   | ✅ Yes (via multiple processes)                                      | ❌ Not true parallelism (concurrent via threads)     |
# | **Runs Concurrently?**  | ❌ Not effectively with threads (GIL)                                | ✅ Yes, threads release GIL during I/O               |
# | **Use Multiple Cores?** | ✅ Yes (processes can use all CPU cores)                             | ❌ No (threads are limited by GIL)                   |
# | **Ideal Use Case**      | Heavy computation tasks                                             | Waiting on I/O or external response                 |

# %% [markdown]
# # ThreadPoolExecutor
# - The ThreadPoolExecutor (from concurrent.futures) is a high-level API that makes managing threads super simple, compared to manually starting and joining them.
#
# ✅ Why use ThreadPoolExecutor?
# Instead of:
#
# - creating Thread() objects,
#
# - manually .start()ing them,
#
# - and calling .join()…
#
# - You can just submit tasks to a thread pool, and Python will handle the rest.
#
# - 🔒 1. A Thread Owns a Task Completely
# - That whole function is assigned to one thread Other threads will not “jump in” or “continue from where it paused”.

# %%
from concurrent.futures import ThreadPoolExecutor
import time

def print_numbers():
    for i in range(5):
        time.sleep(1)
        print(i)

def print_alphabets():
    for i in ['a', 'b', 'c', 'd', 'e']:
        time.sleep(1)
        print(i)

start_time = time.time()

with ThreadPoolExecutor(max_workers=2) as executor:
    executor.submit(print_numbers)
    executor.submit(print_alphabets)
        

end_time = time.time()
print(f"Total execution time: {end_time - start_time:.2f} seconds")
# Out:
# 0
# a
# b1
#
# 2
# c
# 3
# d
# 4
# e
# Total execution time: 5.02 seconds

# %% [markdown]
# ## ❓ What Is a Deadlock?
# - A deadlock happens when two or more threads wait for each other to release resources — but none ever do, so they all get stuck.
# -🧠 What is a Lock?
# -vA Lock in Python (from the threading module) is a mechanism to prevent multiple threads from accessing shared resources at the same time.
# - Think of a Lock like a door lock:
# - Only one thread can hold the lock (open the door).
# - Others must wait until the lock is released.
# ## “If Python threads don’t run in parallel due to the GIL, why do we even need locks?”
#
# ** Python Threads & the GIL
# - CPython (the default Python interpreter) uses a Global Interpreter Lock (GIL).
# - The GIL means: only one thread executes Python bytecode at a time, even if you have multiple cores.
# - So yes — Python threads don't do true parallelism for CPU-bound work. They do concurrency, not parallel execution.
#
#
#
# ## So Why Use Locks?
# Because even concurrent access to shared variables can be unsafe.
#
# ## GIL ≠ Thread-Safety
# - Even though only one thread runs at a time in the Python VM:
# - Python can switch threads in the middle of an operation.
# - This can break multi-step operations like counter += 1, which is:
# - Read counter
# - Add 1
# - Write back
# - These steps can be interrupted between, leading to a race condition.

# %%
import threading

counter = 0
lock = threading.Lock()  # Just to ensure clean output (optional)

def increment():
    global counter
    for _ in range(100000):
        with lock:
            counter += 1
            # Print the thread currently executing
            print(f"{threading.current_thread().name} incremented counter to {counter}")

# Create 2 threads with names
threads = [
    threading.Thread(target=increment, name="Thread-A"),
    threading.Thread(target=increment, name="Thread-B")
]

for t in threads:
    t.start()

for t in threads:
    t.join()

print("Final counter:", counter)
# Out:
# Thread-A incremented counter to 1
# Thread-A incremented counter to 2
# Thread-A incremented counter to 3
# Thread-A incremented counter to 4
# Thread-A incremented counter to 5
# Thread-A incremented counter to 6
# Thread-A incremented counter to 7
# Thread-A incremented counter to 8
# Thread-A incremented counter to 9
# Thread-A incremented counter to 10
# Thread-A incremented counter to 11
# Thread-A incremented counter to 12
# Thread-A incremented counter to 13
# Thread-A incremented counter to 14
# Thread-A incremented counter to 15
# Thread-A incremented counter to 16
# Thread-A incremented counter to 17
# Thread-A incremented counter to 18
# Thread-A incremented counter to 19
# Thread-A incremented counter to 20
# Thread-A incremented counter to 21
# Thread-A incremented counter to 22
# Thread-A incremented counter to 23
# Thread-A incremented counter to 24
# Thread-A incremented counter to 25
# Thread-A incremented counter to 26
# Thread-A incremented counter to 27
# Thread-A incremented counter to 28
# Thread-A incremented counter to 29
# Thread-A incremented counter to 30
# Thread-A incremented counter to 31
# Thread-A incremented counter to 32
# Thread-A incremented counter to 33
# Thread-A incremented counter to 34
# Thread-A incremented counter to 35
# Thread-A incremented counter to 36
# Thread-A incremented counter to 37
# Thread-A incremented counter to 38
# Thread-A incremented counter to 39
# Thread-A incremented counter to 40
# Thread-A incremented counter to 41
# Thread-A incremented counter to 42
# Thread-A incremented counter to 43
# Thread-A incremented counter to 44
# Thread-A incremented counter to 45
# Thread-A incremented counter to 46
# Thread-A incremented counter to 47
# Thread-A incremented counter to 48
# Thread-A incremented counter to 49
# Thread-A incremented counter to 50
# Thread-A incremented counter to 51
# Thread-A incremented counter to 52
# Thread-A incremented counter to 53
# Thread-A incremented counter to 54
# Thread-A incremented counter to 55
# Thread-A incremented counter to 56
# Thread-A incremented counter to 57
# Thread-A incremented counter to 58
# Thread-A incremented counter to 59
# Thread-A incremented counter to 60
# Thread-A incremented counter to 61
# Thread-A incremented counter to 62
# Thread-A incremented counter to 63
# Thread-A incremented counter to 64
# Thread-A incremented counter to 65
# Thread-A incremented counter to 66
# Thread-A incremented counter to 67
# Thread-A incremented counter to 68
# Thread-A incremented counter to 69
# Thread-A incremented counter to 70
# Thread-A incremented counter to 71
# Thread-A incremented counter to 72
# Thread-A incremented counter to 73
# Thread-A incremented counter to 74
# Thread-A incremented counter to 75
# Thread-A incremented counter to 76
# Thread-A incremented counter to 77
# Thread-A incremented counter to 78
# Thread-A incremented counter to 79
# Thread-A incremented counter to 80
# Thread-A incremented counter to 81
# Thread-A incremented counter to 82
# Thread-A incremented counter to 83
# Thread-A incremented counter to 84
# Thread-A incremented counter to 85
# Thread-A incremented counter to 86
# Thread-A incremented counter to 87
# Thread-A incremented counter to 88
# Thread-A incremented counter to 89
# Thread-A incremented counter to 90
# Thread-A incremented counter to 91
# Thread-A incremented counter to 92
# Thread-A incremented counter to 93
# Thread-A incremented counter to 94
# Thread-A incremented counter to 95
# Thread-A incremented counter to 96
# Thread-A incremented counter to 97
# Thread-A incremented counter to 98
# Thread-A incremented counter to 99
# Thread-A incremented counter to 100
# Thread-A incremented counter to 101
# Thread-A incremented counter to 102
# Thread-A incremented counter to 103
# Thread-A incremented counter to 104
# Thread-A incremented counter to 105
# Thread-A incremented counter to 106
# Thread-A incremented counter to 107
# Thread-A incremented counter to 108
# Thread-A incremented counter to 109
# Thread-A incremented counter to 110
# Thread-A incremented counter to 111
# Thread-A incremented counter to 112
# Thread-A incremented counter to 113
# Thread-A incremented counter to 114
# Thread-A incremented counter to 115
# Thread-A incremented counter to 116
# Thread-A incremented counter to 117
# Thread-A incremented counter to 118
# Thread-A incremented counter to 119
# Thread-A incremented counter to 120
# Thread-A incremented counter to 121
# Thread-A incremented counter to 122
# Thread-A incremented counter to 123
# Thread-A incremented counter to 124
# Thread-A incremented counter to 125
# Thread-A incremented counter to 126
# Thread-A incremented counter to 127
# Thread-A incremented counter to 128
# Thread-A incremented counter to 129
# Thread-A incremented counter to 130
# Thread-A incremented counter to 131
# Thread-A incremented counter to 132
# Thread-A incremented counter to 133
# Thread-A incremented counter to 134
# Thread-A incremented counter to 135
# Thread-A incremented counter to 136
# Thread-A incremented counter to 137
# Thread-A incremented counter to 138
# Thread-A incremented counter to 139
# Thread-A incremented counter to 140
# Thread-A incremented counter to 141
# Thread-A incremented counter to 142
# Thread-A incremented counter to 143
# Thread-A incremented counter to 144
# Thread-A incremented counter to 145
# Thread-A incremented counter to 146
# Thread-A incremented counter to 147
# Thread-A incremented counter to 148
# Thread-A incremented counter to 149
# Thread-A incremented counter to 150
# Thread-A incremented counter to 151
# Thread-A incremented counter to 152
# Thread-A incremented counter to 153
# Thread-A incremented counter to 154
# Thread-A incremented counter to 155
# Thread-A incremented counter to 156
# Thread-A incremented counter to 157
# Thread-A incremented counter to 158
# Thread-A incremented counter to 159
# Thread-A incremented counter to 160
# Thread-A incremented counter to 161
# Thread-A incremented counter to 162
# Thread-A incremented counter to 163
# Thread-A incremented counter to 164
# Thread-A incremented counter to 165
# Thread-A incremented counter to 166
# Thread-A incremented counter to 167
# Thread-A incremented counter to 168
# Thread-A incremented counter to 169
# Thread-A incremented counter to 170
# Thread-A incremented counter to 171
# Thread-A incremented counter to 172
# Thread-A incremented counter to 173
# Thread-A incremented counter to 174
# Thread-A incremented counter to 175
# Thread-A incremented counter to 176
# Thread-A incremented counter to 177
# Thread-A incremented counter to 178
# Thread-A incremented counter to 179
# Thread-A incremented counter to 180
# Thread-A incremented counter to 181
# Thread-A incremented counter to 182
# Thread-A incremented counter to 183
# Thread-A incremented counter to 184
# Thread-A incremented counter to 185
# Thread-A incremented counter to 186
# Thread-A incremented counter to 187
# Thread-A incremented counter to 188
# Thread-A incremented counter to 189
# Thread-A incremented counter to 190
# Thread-A incremented counter to 191
# Thread-A incremented counter to 192
# Thread-A incremented counter to 193
# Thread-A incremented counter to 194
# Thread-A incremented counter to 195
# Thread-A incremented counter to 196
# Thread-A incremented counter to 197
# Thread-A incremented counter to 198
# Thread-A incremented counter to 199
# Thread-A incremented counter to 200
# Thread-A incremented counter to 201
# Thread-A incremented counter to 202
# Thread-A incremented counter to 203
# Thread-A incremented counter to 204
# Thread-A incremented counter to 205
# Thread-A incremented counter to 206
# Thread-A incremented counter to 207
# Thread-A incremented counter to 208
# Thread-A incremented counter to 209
# Thread-A incremented counter to 210
# Thread-A incremented counter to 211
# Thread-A incremented counter to 212
# Thread-A incremented counter to 213
# Thread-A incremented counter to 214
# Thread-A incremented counter to 215
# Thread-A incremented counter to 216
# Thread-A incremented counter to 217
# Thread-A incremented counter to 218
# Thread-A incremented counter to 219
# Thread-A incremented counter to 220
# Thread-A incremented counter to 221
# Thread-A incremented counter to 222
# Thread-A incremented counter to 223
# Thread-A incremented counter to 224
# Thread-A incremented counter to 225
# Thread-A incremented counter to 226
# Thread-A incremented counter to 227
# Thread-A incremented counter to 228
# Thread-A incremented counter to 229
# Thread-A incremented counter to 230
# Thread-A incremented counter to 231
# Thread-A incremented counter to 232
# Thread-A incremented counter to 233
# Thread-A incremented counter to 234
# Thread-A incremented counter to 235
# Thread-A incremented counter to 236
# Thread-A incremented counter to 237
# Thread-A incremented counter to 238
# Thread-A incremented counter to 239
# Thread-A incremented counter to 240
# Thread-A incremented counter to 241
# Thread-A incremented counter to 242
# Thread-A incremented counter to 243
# Thread-A incremented counter to 244
# Thread-A incremented counter to 245
# Thread-A incremented counter to 246
# Thread-A incremented counter to 247
# Thread-A incremented counter to 248
# Thread-A incremented counter to 249
# Thread-A incremented counter to 250
# Thread-A incremented counter to 251
# Thread-A incremented counter to 252
# Thread-A incremented counter to 253
# Thread-A incremented counter to 254
# Thread-A incremented counter to 255
# Thread-A incremented counter to 256
# Thread-A incremented counter to 257
# Thread-A incremented counter to 258
# Thread-A incremented counter to 259
# Thread-A incremented counter to 260
# Thread-A incremented counter to 261
# Thread-A incremented counter to 262
# Thread-A incremented counter to 263
# Thread-A incremented counter to 264
# Thread-A incremented counter to 265
# Thread-A incremented counter to 266
# Thread-A incremented counter to 267
# Thread-A incremented counter to 268
# Thread-A incremented counter to 269
# Thread-A incremented counter to 270
# Thread-A incremented counter to 271
# Thread-A incremented counter to 272
# Thread-A incremented counter to 273
# Thread-A incremented counter to 274
# Thread-A incremented counter to 275
# Thread-A incremented counter to 276
# Thread-A incremented counter to 277
# Thread-A incremented counter to 278
# Thread-A incremented counter to 279
# Thread-A incremented counter to 280
# Thread-A incremented counter to 281
# Thread-A incremented counter to 282
# Thread-A incremented counter to 283
# Thread-A incremented counter to 284
# Thread-A incremented counter to 285
# Thread-A incremented counter to 286
# Thread-A incremented counter to 287
# Thread-A incremented counter to 288
# Thread-A incremented counter to 289
# Thread-A incremented counter to 290
# Thread-A incremented counter to 291
# Thread-A incremented counter to 292
# Thread-A incremented counter to 293
# Thread-A incremented counter to 294
# Thread-A incremented counter to 295
# Thread-A incremented counter to 296
# Thread-A incremented counter to 297
# Thread-A incremented counter to 298
# Thread-A incremented counter to 299
# Thread-A incremented counter to 300
# Thread-A incremented counter to 301
# Thread-A incremented counter to 302
# Thread-A incremented counter to 303
# Thread-A incremented counter to 304
# Thread-A incremented counter to 305
# Thread-A incremented counter to 306
# Thread-A incremented counter to 307
# Thread-A incremented counter to 308
# Thread-A incremented counter to 309
# Thread-A incremented counter to 310
# Thread-A incremented counter to 311
# Thread-A incremented counter to 312
# Thread-A incremented counter to 313
# Thread-A incremented counter to 314
# Thread-A incremented counter to 315
# Thread-A incremented counter to 316
# Thread-A incremented counter to 317
# Thread-A incremented counter to 318
# Thread-A incremented counter to 319
# Thread-A incremented counter to 320
# Thread-A incremented counter to 321
# Thread-A incremented counter to 322
# Thread-A incremented counter to 323
# Thread-A incremented counter to 324
# Thread-A incremented counter to 325
# Thread-A incremented counter to 326
# Thread-A incremented counter to 327
# Thread-A incremented counter to 328
# Thread-A incremented counter to 329
# Thread-A incremented counter to 330
# Thread-A incremented counter to 331
# Thread-A incremented counter to 332
# Thread-A incremented counter to 333
# Thread-A incremented counter to 334
# Thread-A incremented counter to 335
# Thread-A incremented counter to 336
# Thread-A incremented counter to 337
# Thread-A incremented counter to 338
# Thread-A incremented counter to 339
# Thread-A incremented counter to 340
# Thread-A incremented counter to 341
# Thread-A incremented counter to 342
# Thread-A incremented counter to 343
# Thread-A incremented counter to 344
# Thread-A incremented counter to 345
# Thread-A incremented counter to 346
# Thread-A incremented counter to 347
# Thread-A incremented counter to 348
# Thread-A incremented counter to 349
# Thread-A incremented counter to 350
# Thread-A incremented counter to 351
# Thread-A incremented counter to 352
# Thread-A incremented counter to 353
# Thread-A incremented counter to 354
# Thread-A incremented counter to 355
# Thread-A incremented counter to 356
# Thread-A incremented counter to 357
# Thread-A incremented counter to 358
# Thread-A incremented counter to 359
# Thread-A incremented counter to 360
# Thread-A incremented counter to 361
# Thread-A incremented counter to 362
# Thread-A incremented counter to 363
# Thread-A incremented counter to 364
# Thread-A incremented counter to 365
# Thread-A incremented counter to 366
# Thread-A incremented counter to 367
# Thread-A incremented counter to 368
# Thread-A incremented counter to 369
# Thread-A incremented counter to 370
# Thread-A incremented counter to 371
# Thread-A incremented counter to 372
# Thread-A incremented counter to 373
# Thread-A incremented counter to 374
# Thread-A incremented counter to 375
# Thread-A incremented counter to 376
# Thread-A incremented counter to 377
# Thread-A incremented counter to 378
# Thread-A incremented counter to 379
# Thread-A incremented counter to 380
# Thread-A incremented counter to 381
# Thread-A incremented counter to 382
# Thread-A incremented counter to 383
# Thread-A incremented counter to 384
# Thread-A incremented counter to 385
# Thread-A incremented counter to 386
# Thread-A incremented counter to 387
# Thread-A incremented counter to 388
# Thread-A incremented counter to 389
# Thread-A incremented counter to 390
# Thread-A incremented counter to 391
# Thread-A incremented counter to 392
# Thread-A incremented counter to 393
# Thread-A incremented counter to 394
# Thread-A incremented counter to 395
# Thread-A incremented counter to 396
# Thread-A incremented counter to 397
# Thread-A incremented counter to 398
# Thread-A incremented counter to 399
# Thread-A incremented counter to 400
# Thread-A incremented counter to 401
# Thread-A incremented counter to 402
# Thread-A incremented counter to 403
# Thread-A incremented counter to 404
# Thread-A incremented counter to 405
# Thread-A incremented counter to 406
# Thread-A incremented counter to 407
# Thread-A incremented counter to 408
# Thread-A incremented counter to 409
# Thread-A incremented counter to 410
# Thread-A incremented counter to 411
# Thread-A incremented counter to 412
# Thread-A incremented counter to 413
# Thread-A incremented counter to 414
# Thread-A incremented counter to 415
# Thread-A incremented counter to 416
# Thread-A incremented counter to 417
# Thread-A incremented counter to 418
# Thread-A incremented counter to 419
# Thread-A incremented counter to 420
# Thread-A incremented counter to 421
# Thread-A incremented counter to 422
# Thread-A incremented counter to 423
# Thread-A incremented counter to 424
# Thread-A incremented counter to 425
# Thread-A incremented counter to 426
# Thread-A incremented counter to 427
# Thread-A incremented counter to 428
# Thread-A incremented counter to 429
# Thread-A incremented counter to 430
# Thread-A incremented counter to 431
# Thread-A incremented counter to 432
# Thread-A incremented counter to 433
# Thread-A incremented counter to 434
# Thread-A incremented counter to 435
# Thread-A incremented counter to 436
# Thread-A incremented counter to 437
# Thread-A incremented counter to 438
# Thread-A incremented counter to 439
# Thread-A incremented counter to 440
# Thread-A incremented counter to 441
# Thread-A incremented counter to 442
# Thread-A incremented counter to 443
# Thread-A incremented counter to 444
# Thread-A incremented counter to 445
# Thread-A incremented counter to 446
# Thread-A incremented counter to 447
# Thread-A incremented counter to 448
# Thread-A incremented counter to 449
# Thread-A incremented counter to 450
# Thread-A incremented counter to 451
# Thread-A incremented counter to 452
# Thread-A incremented counter to 453
# Thread-A incremented counter to 454
# Thread-A incremented counter to 455
# Thread-A incremented counter to 456
# Thread-A incremented counter to 457
# Thread-A incremented counter to 458
# Thread-A incremented counter to 459
# Thread-A incremented counter to 460
# Thread-A incremented counter to 461
# Thread-A incremented counter to 462
# Thread-A incremented counter to 463
# Thread-A incremented counter to 464
# Thread-A incremented counter to 465
# Thread-A incremented counter to 466
# Thread-A incremented counter to 467
# Thread-A incremented counter to 468
# Thread-A incremented counter to 469
# Thread-A incremented counter to 470
# Thread-A incremented counter to 471
# Thread-A incremented counter to 472
# Thread-A incremented counter to 473
# Thread-A incremented counter to 474
# Thread-A incremented counter to 475
# Thread-A incremented counter to 476
# Thread-A incremented counter to 477
# Thread-A incremented counter to 478
# Thread-A incremented counter to 479
# Thread-A incremented counter to 480
# Thread-A incremented counter to 481
# Thread-A incremented counter to 482
# Thread-A incremented counter to 483
# Thread-A incremented counter to 484
# Thread-A incremented counter to 485
# Thread-A incremented counter to 486
# Thread-A incremented counter to 487
# Thread-A incremented counter to 488
# Thread-A incremented counter to 489
# Thread-A incremented counter to 490
# Thread-A incremented counter to 491
# Thread-A incremented counter to 492
# Thread-A incremented counter to 493
# Thread-A incremented counter to 494
# Thread-A incremented counter to 495
# Thread-A incremented counter to 496
# Thread-A incremented counter to 497
# Thread-A incremented counter to 498
# Thread-A incremented counter to 499
# Thread-A incremented counter to 500
# Thread-A incremented counter to 501
# Thread-A incremented counter to 502
# Thread-A incremented counter to 503
# Thread-A incremented counter to 504
# Thread-A incremented counter to 505
# Thread-A incremented counter to 506
# Thread-A incremented counter to 507
# Thread-A incremented counter to 508
# Thread-A incremented counter to 509
# Thread-A incremented counter to 510
# Thread-A incremented counter to 511
# Thread-A incremented counter to 512
# Thread-A incremented counter to 513
# Thread-A incremented counter to 514
# Thread-A incremented counter to 515
# Thread-A incremented counter to 516
# Thread-A incremented counter to 517
# Thread-A incremented counter to 518
# Thread-A incremented counter to 519
# Thread-A incremented counter to 520
# Thread-A incremented counter to 521
# Thread-A incremented counter to 522
# Thread-A incremented counter to 523
# Thread-A incremented counter to 524
# Thread-A incremented counter to 525
# Thread-A incremented counter to 526
# Thread-A incremented counter to 527
# Thread-A incremented counter to 528
# Thread-A incremented counter to 529
# Thread-A incremented counter to 530
# Thread-A incremented counter to 531
# Thread-A incremented counter to 532
# Thread-A incremented counter to 533
# Thread-A incremented counter to 534
# Thread-A incremented counter to 535
# Thread-A incremented counter to 536
# Thread-A incremented counter to 537
# Thread-A incremented counter to 538
# Thread-A incremented counter to 539
# Thread-A incremented counter to 540
# Thread-A incremented counter to 541
# Thread-A incremented counter to 542
# Thread-A incremented counter to 543
# Thread-A incremented counter to 544
# Thread-A incremented counter to 545
# Thread-A incremented counter to 546
# Thread-A incremented counter to 547
# Thread-A incremented counter to 548
# Thread-A incremented counter to 549
# Thread-A incremented counter to 550
# Thread-A incremented counter to 551
# Thread-A incremented counter to 552
# Thread-A incremented counter to 553
# Thread-A incremented counter to 554
# Thread-A incremented counter to 555
# Thread-A incremented counter to 556
# Thread-A incremented counter to 557
# Thread-A incremented counter to 558
# Thread-A incremented counter to 559
# Thread-A incremented counter to 560
# Thread-A incremented counter to 561
# Thread-A incremented counter to 562
# Thread-A incremented counter to 563
# Thread-A incremented counter to 564
# Thread-A incremented counter to 565
# Thread-A incremented counter to 566
# Thread-A incremented counter to 567
# Thread-A incremented counter to 568
# Thread-A incremented counter to 569
# Thread-A incremented counter to 570
# Thread-A incremented counter to 571
# Thread-A incremented counter to 572
# Thread-A incremented counter to 573
# Thread-A incremented counter to 574
# Thread-A incremented counter to 575
# Thread-A incremented counter to 576
# Thread-A incremented counter to 577
# Thread-A incremented counter to 578
# Thread-A incremented counter to 579
# Thread-A incremented counter to 580
# Thread-A incremented counter to 581
# Thread-A incremented counter to 582
# Thread-A incremented counter to 583
# Thread-A incremented counter to 584
# Thread-A incremented counter to 585
# Thread-A incremented counter to 586
# Thread-A incremented counter to 587
# Thread-A incremented counter to 588
# Thread-A incremented counter to 589
# Thread-A incremented counter to 590
# Thread-A incremented counter to 591
# Thread-A incremented counter to 592
# Thread-A incremented counter to 593
# Thread-A incremented counter to 594
# Thread-A incremented counter to 595
# Thread-A incremented counter to 596
# Thread-A incremented counter to 597
# Thread-A incremented counter to 598
# Thread-A incremented counter to 599
# Thread-A incremented counter to 600
# Thread-A incremented counter to 601
# Thread-A incremented counter to 602
# Thread-A incremented counter to 603
# Thread-A incremented counter to 604
# Thread-A incremented counter to 605
# Thread-A incremented counter to 606
# Thread-A incremented counter to 607
# Thread-A incremented counter to 608
# Thread-A incremented counter to 609
# Thread-A incremented counter to 610
# Thread-A incremented counter to 611
# Thread-A incremented counter to 612
# Thread-A incremented counter to 613
# Thread-A incremented counter to 614
# Thread-A incremented counter to 615
# Thread-A incremented counter to 616
# Thread-A incremented counter to 617
# Thread-A incremented counter to 618
# Thread-A incremented counter to 619
# Thread-A incremented counter to 620
# Thread-A incremented counter to 621
# Thread-A incremented counter to 622
# Thread-A incremented counter to 623
# Thread-A incremented counter to 624
# Thread-A incremented counter to 625
# Thread-A incremented counter to 626
# Thread-A incremented counter to 627
# Thread-A incremented counter to 628
# Thread-A incremented counter to 629
# Thread-A incremented counter to 630
# Thread-A incremented counter to 631
# Thread-A incremented counter to 632
# Thread-A incremented counter to 633
# Thread-A incremented counter to 634
# Thread-A incremented counter to 635
# Thread-A incremented counter to 636
# Thread-A incremented counter to 637
# Thread-A incremented counter to 638
# Thread-A incremented counter to 639
# Thread-A incremented counter to 640
# Thread-A incremented counter to 641
# Thread-A incremented counter to 642
# Thread-A incremented counter to 643
# Thread-A incremented counter to 644
# Thread-A incremented counter to 645
# Thread-A incremented counter to 646
# Thread-A incremented counter to 647
# Thread-A incremented counter to 648
# Thread-A incremented counter to 649
# Thread-A incremented counter to 650
# Thread-A incremented counter to 651
# Thread-A incremented counter to 652
# Thread-A incremented counter to 653
# Thread-A incremented counter to 654
# Thread-A incremented counter to 655
# Thread-A incremented counter to 656
# Thread-A incremented counter to 657
# Thread-A incremented counter to 658
# Thread-A incremented counter to 659
# Thread-A incremented counter to 660
# Thread-A incremented counter to 661
# Thread-A incremented counter to 662
# Thread-A incremented counter to 663
# Thread-A incremented counter to 664
# Thread-A incremented counter to 665
# Thread-A incremented counter to 666
# Thread-A incremented counter to 667
# Thread-A incremented counter to 668
# Thread-A incremented counter to 669
# Thread-A incremented counter to 670
# Thread-A incremented counter to 671
# Thread-A incremented counter to 672
# Thread-A incremented counter to 673
# Thread-A incremented counter to 674
# Thread-A incremented counter to 675
# Thread-A incremented counter to 676
# Thread-A incremented counter to 677
# Thread-A incremented counter to 678
# Thread-A incremented counter to 679
# Thread-A incremented counter to 680
# Thread-A incremented counter to 681
# Thread-A incremented counter to 682
# Thread-A incremented counter to 683
# Thread-A incremented counter to 684
# Thread-A incremented counter to 685
# Thread-A incremented counter to 686
# Thread-A incremented counter to 687
# Thread-A incremented counter to 688
# Thread-A incremented counter to 689
# Thread-A incremented counter to 690
# Thread-A incremented counter to 691
# Thread-A incremented counter to 692
# Thread-A incremented counter to 693
# Thread-A incremented counter to 694
# Thread-A incremented counter to 695
# Thread-A incremented counter to 696
# Thread-A incremented counter to 697
# Thread-A incremented counter to 698
# Thread-A incremented counter to 699
# Thread-A incremented counter to 700
# Thread-A incremented counter to 701
# Thread-A incremented counter to 702
# Thread-A incremented counter to 703
# Thread-A incremented counter to 704
# Thread-A incremented counter to 705
# Thread-A incremented counter to 706
# Thread-A incremented counter to 707
# Thread-A incremented counter to 708
# Thread-A incremented counter to 709
# Thread-A incremented counter to 710
# Thread-A incremented counter to 711
# Thread-A incremented counter to 712
# Thread-A incremented counter to 713
# Thread-A incremented counter to 714
# Thread-A incremented counter to 715
# Thread-A incremented counter to 716
# Thread-A incremented counter to 717
# Thread-A incremented counter to 718
# Thread-A incremented counter to 719
# Thread-A incremented counter to 720
# Thread-A incremented counter to 721
# Thread-A incremented counter to 722
# Thread-A incremented counter to 723
# Thread-A incremented counter to 724
# Thread-A incremented counter to 725
# Thread-A incremented counter to 726
# Thread-A incremented counter to 727
# Thread-A incremented counter to 728
# Thread-A incremented counter to 729
# Thread-A incremented counter to 730
# Thread-A incremented counter to 731
# Thread-A incremented counter to 732
# Thread-A incremented counter to 733
# Thread-A incremented counter to 734
# Thread-A incremented counter to 735
# Thread-A incremented counter to 736
# Thread-A incremented counter to 737
# Thread-A incremented counter to 738
# Thread-A incremented counter to 739
# Thread-A incremented counter to 740
# Thread-A incremented counter to 741
# Thread-A incremented counter to 742
# Thread-A incremented counter to 743
# Thread-A incremented counter to 744
# Thread-A incremented counter to 745
# Thread-A incremented counter to 746
# Thread-A incremented counter to 747
# Thread-A incremented counter to 748
# Thread-A incremented counter to 749
# Thread-A incremented counter to 750
# Thread-A incremented counter to 751
# Thread-A incremented counter to 752
# Thread-A incremented counter to 753
# Thread-A incremented counter to 754
# Thread-A incremented counter to 755
# Thread-A incremented counter to 756
# Thread-A incremented counter to 757
# Thread-A incremented counter to 758
# Thread-A incremented counter to 759
# Thread-A incremented counter to 760
# Thread-A incremented counter to 761
# Thread-A incremented counter to 762
# Thread-A incremented counter to 763
# Thread-A incremented counter to 764
# Thread-A incremented counter to 765
# Thread-A incremented counter to 766
# Thread-A incremented counter to 767
# Thread-A incremented counter to 768
# Thread-A incremented counter to 769
# Thread-A incremented counter to 770
# Thread-A incremented counter to 771
# Thread-A incremented counter to 772
# Thread-A incremented counter to 773
# Thread-A incremented counter to 774
# Thread-A incremented counter to 775
# Thread-A incremented counter to 776
# Thread-A incremented counter to 777
# Thread-A incremented counter to 778
# Thread-A incremented counter to 779
# Thread-A incremented counter to 780
# Thread-A incremented counter to 781
# Thread-A incremented counter to 782
# Thread-A incremented counter to 783
# Thread-A incremented counter to 784
# Thread-A incremented counter to 785
# Thread-A incremented counter to 786
# Thread-A incremented counter to 787
# Thread-A incremented counter to 788
# Thread-A incremented counter to 789
# Thread-A incremented counter to 790
# Thread-A incremented counter to 791
# Thread-A incremented counter to 792
# Thread-A incremented counter to 793
# Thread-A incremented counter to 794
# Thread-A incremented counter to 795
# Thread-A incremented counter to 796
# Thread-A incremented counter to 797
# Thread-A incremented counter to 798
# Thread-A incremented counter to 799
# Thread-A incremented counter to 800
# Thread-A incremented counter to 801
# Thread-A incremented counter to 802
# Thread-A incremented counter to 803
# Thread-A incremented counter to 804
# Thread-A incremented counter to 805
# Thread-A incremented counter to 806
# Thread-A incremented counter to 807
# Thread-A incremented counter to 808
# Thread-A incremented counter to 809
# Thread-A incremented counter to 810
# Thread-A incremented counter to 811
# Thread-A incremented counter to 812
# Thread-A incremented counter to 813
# Thread-A incremented counter to 814
# Thread-A incremented counter to 815
# Thread-A incremented counter to 816
# Thread-A incremented counter to 817
# Thread-A incremented counter to 818
# Thread-A incremented counter to 819
# Thread-A incremented counter to 820
# Thread-A incremented counter to 821
# Thread-A incremented counter to 822
# Thread-A incremented counter to 823
# Thread-A incremented counter to 824
# Thread-A incremented counter to 825
# Thread-A incremented counter to 826
# Thread-A incremented counter to 827
# Thread-A incremented counter to 828
# Thread-A incremented counter to 829
# Thread-A incremented counter to 830
# Thread-A incremented counter to 831
# Thread-A incremented counter to 832
# Thread-A incremented counter to 833
# Thread-A incremented counter to 834
# Thread-A incremented counter to 835
# Thread-A incremented counter to 836
# Thread-A incremented counter to 837
# Thread-A incremented counter to 838
# Thread-A incremented counter to 839
# Thread-A incremented counter to 840
# Thread-A incremented counter to 841
# Thread-A incremented counter to 842
# Thread-A incremented counter to 843
# Thread-A incremented counter to 844
# Thread-A incremented counter to 845
# Thread-A incremented counter to 846
# Thread-A incremented counter to 847
# Thread-A incremented counter to 848
# Thread-A incremented counter to 849
# Thread-A incremented counter to 850
# Thread-A incremented counter to 851
# Thread-A incremented counter to 852
# Thread-A incremented counter to 853
# Thread-A incremented counter to 854
# Thread-A incremented counter to 855
# Thread-A incremented counter to 856
# Thread-A incremented counter to 857
# Thread-A incremented counter to 858
# Thread-A incremented counter to 859
# Thread-A incremented counter to 860
# Thread-A incremented counter to 861
# Thread-A incremented counter to 862
# Thread-A incremented counter to 863
# Thread-A incremented counter to 864
# Thread-A incremented counter to 865
# Thread-A incremented counter to 866
# Thread-A incremented counter to 867
# Thread-A incremented counter to 868
# Thread-A incremented counter to 869
# Thread-A incremented counter to 870
# Thread-A incremented counter to 871
# Thread-A incremented counter to 872
# Thread-A incremented counter to 873
# Thread-A incremented counter to 874
# Thread-A incremented counter to 875
# Thread-A incremented counter to 876
# Thread-A incremented counter to 877
# Thread-A incremented counter to 878
# Thread-A incremented counter to 879
# Thread-A incremented counter to 880
# Thread-A incremented counter to 881
# Thread-A incremented counter to 882
# Thread-A incremented counter to 883
# Thread-A incremented counter to 884
# Thread-A incremented counter to 885
# Thread-A incremented counter to 886
# Thread-A incremented counter to 887
# Thread-A incremented counter to 888
# Thread-A incremented counter to 889
# Thread-A incremented counter to 890
# Thread-A incremented counter to 891
# Thread-A incremented counter to 892
# Thread-A incremented counter to 893
# Thread-A incremented counter to 894
# Thread-A incremented counter to 895
# Thread-A incremented counter to 896
# Thread-A incremented counter to 897
# Thread-A incremented counter to 898
# Thread-A incremented counter to 899
# Thread-A incremented counter to 900
# Thread-A incremented counter to 901
# Thread-A incremented counter to 902
# Thread-A incremented counter to 903
# Thread-A incremented counter to 904
# Thread-A incremented counter to 905
# Thread-A incremented counter to 906
# Thread-A incremented counter to 907
# Thread-A incremented counter to 908
# Thread-A incremented counter to 909
# Thread-A incremented counter to 910
# Thread-A incremented counter to 911
# Thread-A incremented counter to 912
# Thread-A incremented counter to 913
# Thread-A incremented counter to 914
# Thread-A incremented counter to 915
# Thread-A incremented counter to 916
# Thread-A incremented counter to 917
# Thread-A incremented counter to 918
# Thread-A incremented counter to 919
# Thread-A incremented counter to 920
# Thread-A incremented counter to 921
# Thread-A incremented counter to 922
# Thread-A incremented counter to 923
# Thread-A incremented counter to 924
# Thread-A incremented counter to 925
# Thread-A incremented counter to 926
# Thread-A incremented counter to 927
# Thread-A incremented counter to 928
# Thread-A incremented counter to 929
# Thread-A incremented counter to 930
# Thread-A incremented counter to 931
# Thread-A incremented counter to 932
# Thread-A incremented counter to 933
# Thread-A incremented counter to 934
# Thread-A incremented counter to 935
# Thread-A incremented counter to 936
# Thread-A incremented counter to 937
# Thread-A incremented counter to 938
# Thread-A incremented counter to 939
# Thread-A incremented counter to 940
# Thread-A incremented counter to 941
# Thread-A incremented counter to 942
# Thread-A incremented counter to 943
# Thread-A incremented counter to 944
# Thread-A incremented counter to 945
# Thread-A incremented counter to 946
# Thread-A incremented counter to 947
# Thread-A incremented counter to 948
# Thread-A incremented counter to 949
# Thread-A incremented counter to 950
# Thread-A incremented counter to 951
# Thread-A incremented counter to 952
# Thread-A incremented counter to 953
# Thread-A incremented counter to 954
# Thread-A incremented counter to 955
# Thread-A incremented counter to 956
# Thread-A incremented counter to 957
# Thread-A incremented counter to 958
# Thread-A incremented counter to 959
# Thread-A incremented counter to 960
# Thread-A incremented counter to 961
# Thread-A incremented counter to 962
# Thread-A incremented counter to 963
# Thread-A incremented counter to 964
# Thread-A incremented counter to 965
# Thread-A incremented counter to 966
# Thread-A incremented counter to 967
# Thread-A incremented counter to 968
# Thread-A incremented counter to 969
# Thread-A incremented counter to 970
# Thread-A incremented counter to 971
# Thread-A incremented counter to 972
# Thread-A incremented counter to 973
# Thread-A incremented counter to 974
# Thread-A incremented counter to 975
# Thread-A incremented counter to 976
# Thread-A incremented counter to 977
# Thread-A incremented counter to 978
# Thread-A incremented counter to 979
# Thread-A incremented counter to 980
# Thread-A incremented counter to 981
# Thread-A incremented counter to 982
# Thread-A incremented counter to 983
# Thread-A incremented counter to 984
# Thread-A incremented counter to 985
# Thread-A incremented counter to 986
# Thread-A incremented counter to 987
# Thread-A incremented counter to 988
# Thread-A incremented counter to 989
# Thread-A incremented counter to 990
# Thread-A incremented counter to 991
# Thread-A incremented counter to 992
# Thread-A incremented counter to 993
# Thread-A incremented counter to 994
# Thread-A incremented counter to 995
# Thread-A incremented counter to 996
# Thread-A incremented counter to 997
# Thread-A incremented counter to 998
# Thread-A incremented counter to 999
# Thread-A incremented counter to 1000
# Thread-B incremented counter to 1001
# Thread-B incremented counter to 1002
# Thread-B incremented counter to 1003
# Thread-B incremented counter to 1004
# Thread-B incremented counter to 1005
# Thread-B incremented counter to 1006
# Thread-B incremented counter to 1007
# Thread-B incremented counter to 1008
# Thread-B incremented counter to 1009
# Thread-B incremented counter to 1010
# Thread-B incremented counter to 1011
# Thread-B incremented counter to 1012
# Thread-B incremented counter to 1013
# Thread-B incremented counter to 1014
# Thread-B incremented counter to 1015
# Thread-B incremented counter to 1016
# Thread-B incremented counter to 1017
# Thread-B incremented counter to 1018
# Thread-B incremented counter to 1019
# Thread-B incremented counter to 1020
# Thread-B incremented counter to 1021
# Thread-B incremented counter to 1022
# Thread-B incremented counter to 1023
# Thread-B incremented counter to 1024
# Thread-B incremented counter to 1025
# Thread-B incremented counter to 1026
# Thread-B incremented counter to 1027
# Thread-B incremented counter to 1028
# Thread-B incremented counter to 1029
# Thread-B incremented counter to 1030
# Thread-B incremented counter to 1031
# Thread-B incremented counter to 1032
# Thread-B incremented counter to 1033
# Thread-B incremented counter to 1034
# Thread-B incremented counter to 1035
# Thread-B incremented counter to 1036
# Thread-B incremented counter to 1037
# Thread-B incremented counter to 1038
# Thread-B incremented counter to 1039
# Thread-B incremented counter to 1040
# Thread-B incremented counter to 1041
# Thread-B incremented counter to 1042
# Thread-B incremented counter to 1043
# Thread-B incremented counter to 1044
# Thread-B incremented counter to 1045
# Thread-B incremented counter to 1046
# Thread-B incremented counter to 1047
# Thread-B incremented counter to 1048
# Thread-B incremented counter to 1049
# Thread-B incremented counter to 1050
# Thread-B incremented counter to 1051
# Thread-B incremented counter to 1052
# Thread-B incremented counter to 1053
# Thread-B incremented counter to 1054
# Thread-B incremented counter to 1055
# Thread-B incremented counter to 1056
# Thread-B incremented counter to 1057
# Thread-B incremented counter to 1058
# Thread-B incremented counter to 1059
# Thread-B incremented counter to 1060
# Thread-B incremented counter to 1061
# Thread-B incremented counter to 1062
# Thread-B incremented counter to 1063
# Thread-B incremented counter to 1064
# Thread-B incremented counter to 1065
# Thread-B incremented counter to 1066
# Thread-B incremented counter to 1067
# Thread-B incremented counter to 1068
# Thread-B incremented counter to 1069
# Thread-B incremented counter to 1070
# Thread-B incremented counter to 1071
# Thread-B incremented counter to 1072
# Thread-B incremented counter to 1073
# Thread-B incremented counter to 1074
# Thread-B incremented counter to 1075
# Thread-B incremented counter to 1076
# Thread-B incremented counter to 1077
# Thread-B incremented counter to 1078
# Thread-B incremented counter to 1079
# Thread-B incremented counter to 1080
# Thread-B incremented counter to 1081
# Thread-B incremented counter to 1082
# Thread-B incremented counter to 1083
# Thread-B incremented counter to 1084
# Thread-B incremented counter to 1085
# Thread-B incremented counter to 1086
# Thread-B incremented counter to 1087
# Thread-B incremented counter to 1088
# Thread-B incremented counter to 1089
# Thread-B incremented counter to 1090
# Thread-B incremented counter to 1091
# Thread-B incremented counter to 1092
# Thread-B incremented counter to 1093
# Thread-B incremented counter to 1094
# Thread-B incremented counter to 1095
# Thread-B incremented counter to 1096
# Thread-B incremented counter to 1097
# Thread-B incremented counter to 1098
# Thread-B incremented counter to 1099
# Thread-B incremented counter to 1100
# Thread-B incremented counter to 1101
# Thread-B incremented counter to 1102
# Thread-B incremented counter to 1103
# Thread-B incremented counter to 1104
# Thread-B incremented counter to 1105
# Thread-B incremented counter to 1106
# Thread-B incremented counter to 1107
# Thread-B incremented counter to 1108
# Thread-B incremented counter to 1109
# Thread-B incremented counter to 1110
# Thread-B incremented counter to 1111
# Thread-B incremented counter to 1112
# Thread-B incremented counter to 1113
# Thread-B incremented counter to 1114
# Thread-B incremented counter to 1115
# Thread-B incremented counter to 1116
# Thread-B incremented counter to 1117
# Thread-B incremented counter to 1118
# Thread-B incremented counter to 1119
# Thread-B incremented counter to 1120
# Thread-B incremented counter to 1121
# Thread-B incremented counter to 1122
# Thread-B incremented counter to 1123
# Thread-B incremented counter to 1124
# Thread-B incremented counter to 1125
# Thread-B incremented counter to 1126
# Thread-B incremented counter to 1127
# Thread-B incremented counter to 1128
# Thread-B incremented counter to 1129
# Thread-B incremented counter to 1130
# Thread-B incremented counter to 1131
# Thread-B incremented counter to 1132
# Thread-B incremented counter to 1133
# Thread-B incremented counter to 1134
# Thread-B incremented counter to 1135
# Thread-B incremented counter to 1136
# Thread-B incremented counter to 1137
# Thread-B incremented counter to 1138
# Thread-B incremented counter to 1139
# Thread-B incremented counter to 1140
# Thread-B incremented counter to 1141
# Thread-B incremented counter to 1142
# Thread-B incremented counter to 1143
# Thread-B incremented counter to 1144
# Thread-B incremented counter to 1145
# Thread-B incremented counter to 1146
# Thread-B incremented counter to 1147
# Thread-B incremented counter to 1148
# Thread-B incremented counter to 1149
# Thread-B incremented counter to 1150
# Thread-B incremented counter to 1151
# Thread-B incremented counter to 1152
# Thread-B incremented counter to 1153
# Thread-B incremented counter to 1154
# Thread-B incremented counter to 1155
# Thread-B incremented counter to 1156
# Thread-B incremented counter to 1157
# Thread-B incremented counter to 1158
# Thread-B incremented counter to 1159
# Thread-B incremented counter to 1160
# Thread-B incremented counter to 1161
# Thread-B incremented counter to 1162
# Thread-B incremented counter to 1163
# Thread-B incremented counter to 1164
# Thread-B incremented counter to 1165
# Thread-B incremented counter to 1166
# Thread-B incremented counter to 1167
# Thread-B incremented counter to 1168
# Thread-B incremented counter to 1169
# Thread-B incremented counter to 1170
# Thread-B incremented counter to 1171
# Thread-B incremented counter to 1172
# Thread-B incremented counter to 1173
# Thread-B incremented counter to 1174
# Thread-B incremented counter to 1175
# Thread-B incremented counter to 1176
# Thread-B incremented counter to 1177
# Thread-B incremented counter to 1178
# Thread-B incremented counter to 1179
# Thread-B incremented counter to 1180
# Thread-B incremented counter to 1181
# Thread-B incremented counter to 1182
# Thread-B incremented counter to 1183
# Thread-B incremented counter to 1184
# Thread-B incremented counter to 1185
# Thread-B incremented counter to 1186
# Thread-B incremented counter to 1187
# Thread-B incremented counter to 1188
# Thread-B incremented counter to 1189
# Thread-B incremented counter to 1190
# Thread-B incremented counter to 1191
# Thread-B incremented counter to 1192
# Thread-B incremented counter to 1193
# Thread-B incremented counter to 1194
# Thread-B incremented counter to 1195
# Thread-B incremented counter to 1196
# Thread-B incremented counter to 1197
# Thread-B incremented counter to 1198
# Thread-B incremented counter to 1199
# Thread-B incremented counter to 1200
# Thread-B incremented counter to 1201
# Thread-B incremented counter to 1202
# Thread-B incremented counter to 1203
# Thread-B incremented counter to 1204
# Thread-B incremented counter to 1205
# Thread-B incremented counter to 1206
# Thread-B incremented counter to 1207
# Thread-B incremented counter to 1208
# Thread-B incremented counter to 1209
# Thread-B incremented counter to 1210
# Thread-B incremented counter to 1211
# Thread-B incremented counter to 1212
# Thread-B incremented counter to 1213
# Thread-B incremented counter to 1214
# Thread-B incremented counter to 1215
# Thread-B incremented counter to 1216
# Thread-B incremented counter to 1217
# Thread-B incremented counter to 1218
# Thread-B incremented counter to 1219
# Thread-B incremented counter to 1220
# Thread-B incremented counter to 1221
# Thread-B incremented counter to 1222
# Thread-B incremented counter to 1223
# Thread-B incremented counter to 1224
# Thread-B incremented counter to 1225
# Thread-B incremented counter to 1226
# Thread-B incremented counter to 1227
# Thread-B incremented counter to 1228
# Thread-B incremented counter to 1229
# Thread-B incremented counter to 1230
# Thread-B incremented counter to 1231
# Thread-B incremented counter to 1232
# Thread-B incremented counter to 1233
# Thread-B incremented counter to 1234
# Thread-B incremented counter to 1235
# Thread-B incremented counter to 1236
# Thread-B incremented counter to 1237
# Thread-B incremented counter to 1238
# Thread-B incremented counter to 1239
# Thread-B incremented counter to 1240
# Thread-B incremented counter to 1241
# Thread-B incremented counter to 1242
# Thread-B incremented counter to 1243
# Thread-B incremented counter to 1244
# Thread-B incremented counter to 1245
# Thread-B incremented counter to 1246
# Thread-B incremented counter to 1247
# Thread-B incremented counter to 1248
# Thread-B incremented counter to 1249
# Thread-B incremented counter to 1250
# Thread-B incremented counter to 1251
# Thread-B incremented counter to 1252
# Thread-B incremented counter to 1253
# Thread-B incremented counter to 1254
# Thread-B incremented counter to 1255
# Thread-B incremented counter to 1256
# Thread-B incremented counter to 1257
# Thread-B incremented counter to 1258
# Thread-B incremented counter to 1259
# Thread-B incremented counter to 1260
# Thread-B incremented counter to 1261
# Thread-B incremented counter to 1262
# Thread-B incremented counter to 1263
# Thread-B incremented counter to 1264
# Thread-B incremented counter to 1265
# Thread-B incremented counter to 1266
# Thread-B incremented counter to 1267
# Thread-B incremented counter to 1268
# Thread-B incremented counter to 1269
# Thread-B incremented counter to 1270
# Thread-B incremented counter to 1271
# Thread-B incremented counter to 1272
# Thread-B incremented counter to 1273
# Thread-B incremented counter to 1274
# Thread-B incremented counter to 1275
# Thread-B incremented counter to 1276
# Thread-B incremented counter to 1277
# Thread-B incremented counter to 1278
# Thread-B incremented counter to 1279
# Thread-B incremented counter to 1280
# Thread-B incremented counter to 1281
# Thread-B incremented counter to 1282
# Thread-B incremented counter to 1283
# Thread-B incremented counter to 1284
# Thread-B incremented counter to 1285
# Thread-B incremented counter to 1286
# Thread-B incremented counter to 1287
# Thread-B incremented counter to 1288
# Thread-B incremented counter to 1289
# Thread-B incremented counter to 1290
# Thread-B incremented counter to 1291
# Thread-B incremented counter to 1292
# Thread-B incremented counter to 1293
# Thread-B incremented counter to 1294
# Thread-B incremented counter to 1295
# Thread-B incremented counter to 1296
# Thread-B incremented counter to 1297
# Thread-B incremented counter to 1298
# Thread-B incremented counter to 1299
# Thread-B incremented counter to 1300
# Thread-B incremented counter to 1301
# Thread-B incremented counter to 1302
# Thread-B incremented counter to 1303
# Thread-B incremented counter to 1304
# Thread-B incremented counter to 1305
# Thread-B incremented counter to 1306
# Thread-B incremented counter to 1307
# Thread-B incremented counter to 1308
# Thread-B incremented counter to 1309
# Thread-B incremented counter to 1310
# Thread-B incremented counter to 1311
# Thread-B incremented counter to 1312
# Thread-B incremented counter to 1313
# Thread-B incremented counter to 1314
# Thread-B incremented counter to 1315
# Thread-B incremented counter to 1316
# Thread-B incremented counter to 1317
# Thread-B incremented counter to 1318
# Thread-B incremented counter to 1319
# Thread-B incremented counter to 1320
# Thread-B incremented counter to 1321
# Thread-B incremented counter to 1322
# Thread-B incremented counter to 1323
# Thread-B incremented counter to 1324
# Thread-B incremented counter to 1325
# Thread-B incremented counter to 1326
# Thread-B incremented counter to 1327
# ...
# Thread-B incremented counter to 1570
# Thread-B incremented counter to 1571
# Thread-B incremented counter to 1572
# Thread-B incremented counter to 1573
# Thread-B incremented counter to 1574
# Thread-B incremented counter to 1575
# Thread-B incremented counter to 1576
# Thread-B incremented counter to 1577
# Thread-B incremented counter to 1578
# Thread-B incremented counter to 1579
# Thread-B incremented counter to 1580
# Thread-B incremented counter to 1581
# Thread-B incremented counter to 1582
# Thread-B incremented counter to 1583
# Thread-B incremented counter to 1584
# Thread-B incremented counter to 1585
# Thread-B incremented counter to 1586
# Thread-B incremented counter to 1587
# Thread-B incremented counter to 1588
# Thread-B incremented counter to 1589
# Thread-B incremented counter to 1590
# Thread-B incremented counter to 1591
# Thread-B incremented counter to 1592
# Thread-B incremented counter to 1593
# Thread-B incremented counter to 1594
# Thread-B incremented counter to 1595
# Thread-B incremented counter to 1596
# Thread-B incremented counter to 1597
# Thread-B incremented counter to 1598
# Thread-B incremented counter to 1599
# Thread-B incremented counter to 1600
# Thread-B incremented counter to 1601
# Thread-B incremented counter to 1602
# Thread-B incremented counter to 1603
# Thread-B incremented counter to 1604
# Thread-B incremented counter to 1605
# Thread-B incremented counter to 1606
# Thread-B incremented counter to 1607
# Thread-B incremented counter to 1608
# Thread-B incremented counter to 1609
# Thread-B incremented counter to 1610
# Thread-B incremented counter to 1611
# Thread-B incremented counter to 1612
# Thread-B incremented counter to 1613
# Thread-B incremented counter to 1614
# Thread-B incremented counter to 1615
# Thread-B incremented counter to 1616
# Thread-B incremented counter to 1617
# Thread-B incremented counter to 1618
# Thread-B incremented counter to 1619
# Thread-B incremented counter to 1620
# Thread-B incremented counter to 1621
# Thread-B incremented counter to 1622
# Thread-B incremented counter to 1623
# Thread-B incremented counter to 1624
# Thread-B incremented counter to 1625
# Thread-B incremented counter to 1626
# Thread-B incremented counter to 1627
# Thread-B incremented counter to 1628
# Thread-B incremented counter to 1629
# Thread-B incremented counter to 1630
# Thread-B incremented counter to 1631
# Thread-B incremented counter to 1632
# Thread-B incremented counter to 1633
# Thread-B incremented counter to 1634
# Thread-B incremented counter to 1635
# Thread-B incremented counter to 1636
# Thread-B incremented counter to 1637
# Thread-B incremented counter to 1638
# Thread-B incremented counter to 1639
# Thread-B incremented counter to 1640
# Thread-B incremented counter to 1641
# Thread-B incremented counter to 1642
# Thread-B incremented counter to 1643
# Thread-B incremented counter to 1644
# Thread-B incremented counter to 1645
# Thread-B incremented counter to 1646
# Thread-B incremented counter to 1647
# Thread-B incremented counter to 1648
# Thread-B incremented counter to 1649
# Thread-B incremented counter to 1650
# Thread-B incremented counter to 1651
# Thread-B incremented counter to 1652
# Thread-B incremented counter to 1653
# Thread-B incremented counter to 1654
# Thread-B incremented counter to 1655
# Thread-B incremented counter to 1656
# Thread-B incremented counter to 1657
# Thread-B incremented counter to 1658
# Thread-B incremented counter to 1659
# Thread-B incremented counter to 1660
# Thread-B incremented counter to 1661
# Thread-B incremented counter to 1662
# Thread-B incremented counter to 1663
# Thread-B incremented counter to 1664
# Thread-B incremented counter to 1665
# Thread-B incremented counter to 1666
# Thread-B incremented counter to 1667
# Thread-B incremented counter to 1668
# Thread-B incremented counter to 1669
# Thread-B incremented counter to 1670
# Thread-B incremented counter to 1671
# Thread-B incremented counter to 1672
# Thread-B incremented counter to 1673
# Thread-B incremented counter to 1674
# Thread-B incremented counter to 1675
# Thread-B incremented counter to 1676
# Thread-B incremented counter to 1677
# Thread-B incremented counter to 1678
# Thread-B incremented counter to 1679
# Thread-B incremented counter to 1680
# Thread-B incremented counter to 1681
# Thread-B incremented counter to 1682
# Thread-B incremented counter to 1683
# Thread-B incremented counter to 1684
# Thread-B incremented counter to 1685
# Thread-B incremented counter to 1686
# Thread-B incremented counter to 1687
# Thread-B incremented counter to 1688
# Thread-B incremented counter to 1689
# Thread-B incremented counter to 1690
# Thread-B incremented counter to 1691
# Thread-B incremented counter to 1692
# Thread-B incremented counter to 1693
# Thread-B incremented counter to 1694
# Thread-B incremented counter to 1695
# Thread-B incremented counter to 1696
# Thread-B incremented counter to 1697
# Thread-B incremented counter to 1698
# Thread-B incremented counter to 1699
# Thread-B incremented counter to 1700
# Thread-B incremented counter to 1701
# Thread-B incremented counter to 1702
# Thread-B incremented counter to 1703
# Thread-B incremented counter to 1704
# Thread-B incremented counter to 1705
# Thread-B incremented counter to 1706
# Thread-B incremented counter to 1707
# Thread-B incremented counter to 1708
# Thread-B incremented counter to 1709
# Thread-B incremented counter to 1710
# Thread-B incremented counter to 1711
# Thread-B incremented counter to 1712
# Thread-B incremented counter to 1713
# Thread-B incremented counter to 1714
# Thread-B incremented counter to 1715
# Thread-B incremented counter to 1716
# Thread-B incremented counter to 1717
# Thread-B incremented counter to 1718
# Thread-B incremented counter to 1719
# Thread-B incremented counter to 1720
# Thread-B incremented counter to 1721
# Thread-B incremented counter to 1722
# Thread-B incremented counter to 1723
# Thread-B incremented counter to 1724
# Thread-B incremented counter to 1725
# Thread-B incremented counter to 1726
# Thread-B incremented counter to 1727
# Thread-B incremented counter to 1728
# Thread-B incremented counter to 1729
# Thread-B incremented counter to 1730
# Thread-B incremented counter to 1731
# Thread-B incremented counter to 1732
# Thread-B incremented counter to 1733
# Thread-B incremented counter to 1734
# Thread-B incremented counter to 1735
# Thread-B incremented counter to 1736
# Thread-B incremented counter to 1737
# Thread-B incremented counter to 1738
# Thread-B incremented counter to 1739
# Thread-B incremented counter to 1740
# Thread-B incremented counter to 1741
# Thread-B incremented counter to 1742
# Thread-B incremented counter to 1743
# Thread-B incremented counter to 1744
# Thread-B incremented counter to 1745
# Thread-B incremented counter to 1746
# Thread-B incremented counter to 1747
# Thread-B incremented counter to 1748
# Thread-B incremented counter to 1749
# Thread-B incremented counter to 1750
# Thread-B incremented counter to 1751
# Thread-B incremented counter to 1752
# Thread-B incremented counter to 1753
# Thread-B incremented counter to 1754
# Thread-B incremented counter to 1755
# Thread-B incremented counter to 1756
# Thread-B incremented counter to 1757
# Thread-B incremented counter to 1758
# Thread-B incremented counter to 1759
# Thread-B incremented counter to 1760
# Thread-B incremented counter to 1761
# Thread-B incremented counter to 1762
# Thread-B incremented counter to 1763
# Thread-B incremented counter to 1764
# Thread-B incremented counter to 1765
# Thread-B incremented counter to 1766
# Thread-B incremented counter to 1767
# Thread-B incremented counter to 1768
# Thread-B incremented counter to 1769
# Thread-B incremented counter to 1770
# Thread-B incremented counter to 1771
# Thread-B incremented counter to 1772
# Thread-B incremented counter to 1773
# Thread-B incremented counter to 1774
# Thread-B incremented counter to 1775
# Thread-B incremented counter to 1776
# Thread-B incremented counter to 1777
# Thread-B incremented counter to 1778
# Thread-B incremented counter to 1779
# Thread-B incremented counter to 1780
# Thread-B incremented counter to 1781
# Thread-B incremented counter to 1782
# Thread-B incremented counter to 1783
# Thread-B incremented counter to 1784
# Thread-B incremented counter to 1785
# Thread-B incremented counter to 1786
# Thread-B incremented counter to 1787
# Thread-B incremented counter to 1788
# Thread-B incremented counter to 1789
# Thread-B incremented counter to 1790
# Thread-B incremented counter to 1791
# Thread-B incremented counter to 1792
# Thread-B incremented counter to 1793
# Thread-B incremented counter to 1794
# Thread-B incremented counter to 1795
# Thread-B incremented counter to 1796
# Thread-B incremented counter to 1797
# Thread-B incremented counter to 1798
# Thread-B incremented counter to 1799
# Thread-B incremented counter to 1800
# Thread-B incremented counter to 1801
# Thread-B incremented counter to 1802
# Thread-B incremented counter to 1803
# Thread-B incremented counter to 1804
# Thread-B incremented counter to 1805
# Thread-B incremented counter to 1806
# Thread-B incremented counter to 1807
# Thread-B incremented counter to 1808
# Thread-B incremented counter to 1809
# Thread-B incremented counter to 1810
# Thread-B incremented counter to 1811
# Thread-B incremented counter to 1812
# Thread-B incremented counter to 1813
# Thread-B incremented counter to 1814
# Thread-B incremented counter to 1815
# Thread-B incremented counter to 1816
# Thread-B incremented counter to 1817
# Thread-B incremented counter to 1818
# Thread-B incremented counter to 1819
# Thread-B incremented counter to 1820
# Thread-B incremented counter to 1821
# Thread-B incremented counter to 1822
# Thread-B incremented counter to 1823
# Thread-B incremented counter to 1824
# Thread-B incremented counter to 1825
# Thread-B incremented counter to 1826
# Thread-B incremented counter to 1827
# Thread-B incremented counter to 1828
# Thread-B incremented counter to 1829
# Thread-B incremented counter to 1830
# Thread-B incremented counter to 1831
# Thread-B incremented counter to 1832
# Thread-B incremented counter to 1833
# Thread-B incremented counter to 1834
# Thread-B incremented counter to 1835
# Thread-B incremented counter to 1836
# Thread-B incremented counter to 1837
# Thread-B incremented counter to 1838
# Thread-B incremented counter to 1839
# Thread-B incremented counter to 1840
# Thread-B incremented counter to 1841
# Thread-B incremented counter to 1842
# Thread-B incremented counter to 1843
# Thread-B incremented counter to 1844
# Thread-B incremented counter to 1845
# Thread-B incremented counter to 1846
# Thread-B incremented counter to 1847
# Thread-B incremented counter to 1848
# Thread-B incremented counter to 1849
# Thread-B incremented counter to 1850
# Thread-B incremented counter to 1851
# Thread-B incremented counter to 1852
# Thread-B incremented counter to 1853
# Thread-B incremented counter to 1854
# Thread-B incremented counter to 1855
# Thread-B incremented counter to 1856
# Thread-B incremented counter to 1857
# Thread-B incremented counter to 1858
# Thread-B incremented counter to 1859
# Thread-B incremented counter to 1860
# Thread-B incremented counter to 1861
# Thread-B incremented counter to 1862
# Thread-B incremented counter to 1863
# Thread-B incremented counter to 1864
# Thread-B incremented counter to 1865
# Thread-B incremented counter to 1866
# Thread-B incremented counter to 1867
# Thread-B incremented counter to 1868
# Thread-B incremented counter to 1869
# Thread-B incremented counter to 1870
# Thread-B incremented counter to 1871
# Thread-B incremented counter to 1872
# Thread-B incremented counter to 1873
# Thread-B incremented counter to 1874
# Thread-B incremented counter to 1875
# Thread-B incremented counter to 1876
# Thread-B incremented counter to 1877
# Thread-B incremented counter to 1878
# Thread-B incremented counter to 1879
# Thread-B incremented counter to 1880
# Thread-B incremented counter to 1881
# Thread-B incremented counter to 1882
# Thread-B incremented counter to 1883
# Thread-B incremented counter to 1884
# Thread-B incremented counter to 1885
# Thread-B incremented counter to 1886
# Thread-B incremented counter to 1887
# Thread-B incremented counter to 1888
# Thread-B incremented counter to 1889
# Thread-B incremented counter to 1890
# Thread-B incremented counter to 1891
# Thread-B incremented counter to 1892
# Thread-B incremented counter to 1893
# Thread-B incremented counter to 1894
# Thread-B incremented counter to 1895
# Thread-B incremented counter to 1896
# Thread-B incremented counter to 1897
# Thread-B incremented counter to 1898
# Thread-B incremented counter to 1899
# Thread-B incremented counter to 1900
# Thread-B incremented counter to 1901
# Thread-B incremented counter to 1902
# Thread-B incremented counter to 1903
# Thread-B incremented counter to 1904
# Thread-B incremented counter to 1905
# Thread-B incremented counter to 1906
# Thread-B incremented counter to 1907
# Thread-B incremented counter to 1908
# Thread-B incremented counter to 1909
# Thread-B incremented counter to 1910
# Thread-B incremented counter to 1911
# Thread-B incremented counter to 1912
# Thread-B incremented counter to 1913
# Thread-B incremented counter to 1914
# Thread-B incremented counter to 1915
# Thread-B incremented counter to 1916
# Thread-B incremented counter to 1917
# Thread-B incremented counter to 1918
# Thread-B incremented counter to 1919
# Thread-B incremented counter to 1920
# Thread-B incremented counter to 1921
# Thread-B incremented counter to 1922
# Thread-B incremented counter to 1923
# Thread-B incremented counter to 1924
# Thread-B incremented counter to 1925
# Thread-B incremented counter to 1926
# Thread-B incremented counter to 1927
# Thread-B incremented counter to 1928
# Thread-B incremented counter to 1929
# Thread-B incremented counter to 1930
# Thread-B incremented counter to 1931
# Thread-B incremented counter to 1932
# Thread-B incremented counter to 1933
# Thread-B incremented counter to 1934
# Thread-B incremented counter to 1935
# Thread-B incremented counter to 1936
# Thread-B incremented counter to 1937
# Thread-B incremented counter to 1938
# Thread-B incremented counter to 1939
# Thread-B incremented counter to 1940
# Thread-B incremented counter to 1941
# Thread-B incremented counter to 1942
# Thread-B incremented counter to 1943
# Thread-B incremented counter to 1944
# Thread-B incremented counter to 1945
# Thread-B incremented counter to 1946
# Thread-B incremented counter to 1947
# Thread-B incremented counter to 1948
# Thread-B incremented counter to 1949
# Thread-B incremented counter to 1950
# Thread-B incremented counter to 1951
# Thread-B incremented counter to 1952
# Thread-B incremented counter to 1953
# Thread-B incremented counter to 1954
# Thread-B incremented counter to 1955
# Thread-B incremented counter to 1956
# Thread-B incremented counter to 1957
# Thread-B incremented counter to 1958
# Thread-B incremented counter to 1959
# Thread-B incremented counter to 1960
# Thread-B incremented counter to 1961
# Thread-B incremented counter to 1962
# Thread-B incremented counter to 1963
# Thread-B incremented counter to 1964
# Thread-B incremented counter to 1965
# Thread-B incremented counter to 1966
# Thread-B incremented counter to 1967
# Thread-B incremented counter to 1968
# Thread-B incremented counter to 1969
# Thread-B incremented counter to 1970
# Thread-B incremented counter to 1971
# Thread-B incremented counter to 1972
# Thread-B incremented counter to 1973
# Thread-B incremented counter to 1974
# Thread-B incremented counter to 1975
# Thread-B incremented counter to 1976
# Thread-B incremented counter to 1977
# Thread-B incremented counter to 1978
# Thread-B incremented counter to 1979
# Thread-B incremented counter to 1980
# Thread-B incremented counter to 1981
# Thread-B incremented counter to 1982
# Thread-B incremented counter to 1983
# Thread-B incremented counter to 1984
# Thread-B incremented counter to 1985
# Thread-B incremented counter to 1986
# Thread-B incremented counter to 1987
# Thread-B incremented counter to 1988
# Thread-B incremented counter to 1989
# Thread-B incremented counter to 1990
# Thread-B incremented counter to 1991
# Thread-B incremented counter to 1992
# Thread-B incremented counter to 1993
# Thread-B incremented counter to 1994
# Thread-B incremented counter to 1995
# Thread-B incremented counter to 1996
# Thread-B incremented counter to 1997
# Thread-B incremented counter to 1998
# Thread-B incremented counter to 1999
# Thread-B incremented counter to 2000
# Final counter: 2000

# %% [markdown]
# # Output Example (shortened):
#
# Thread-A incremented counter to 1
# Thread-B incremented counter to 2
# Thread-A incremented counter to 3
# ...
# Final counter: 2000
#
# - When we have shared memory data its not safe to move on without lock because in python we cannot assume if thread 1 one is running it will run till end untill its task is done i between it might pause and other thread might come into action

# %% [markdown]
# # 🧠 Real-world Analogy:
# - Think of two people at a narrow door.
# - Person A is waiting for Person B to move.
# - Person B is also waiting for Person A to move.
# - So... both are stuck. 🧍‍♂️🚪🧍‍♀️

# %%
# Do not run the code for deadlock example as it will cause the program to hang indefinitely.

# %%
import threading
import time

lock1 = threading.Lock()
lock2 = threading.Lock()

def thread1():
    with lock1:
        print("Thread 1 acquired lock1")
        time.sleep(1)
        with lock2:
            print("Thread 1 acquired lock2")

def thread2():
    with lock2:
        print("Thread 2 acquired lock2")
        time.sleep(1)
        with lock1:
            print("Thread 2 acquired lock1")

t1 = threading.Thread(target=thread1)
t2 = threading.Thread(target=thread2)

t1.start()
t2.start()

t1.join()
t2.join()

print("Done")

# %% [markdown]
# | Thread 1                         | Thread 2                         |
# | -------------------------------- | -------------------------------- |
# | Gets `lock1` ✅                   | Gets `lock2` ✅                   |
# | Waits for `lock2` ❌ (held by T2) | Waits for `lock1` ❌ (held by T1) |
# | Both are stuck forever 😵        | Both are stuck forever 😵        |
#
# Thread 1 acquired lock1
# Thread 2 acquired lock2
# And Your program hangsssssssssssss

# %%
# Preventing Deadlocks with Consistent Locking Order

# %%
import threading
import time

# Create two locks
lock1 = threading.Lock()
lock2 = threading.Lock()

def thread1():
    print("Thread 1 trying to acquire lock1")
    with lock1:
        print("Thread 1 acquired lock1")
        time.sleep(1)
        print("Thread 1 trying to acquire lock2")
        with lock2:
            print("Thread 1 acquired lock2")
            print("Thread 1 is doing work")
        print("Thread 1 released lock2")
    print("Thread 1 released lock1")

def thread2():
    print("Thread 2 trying to acquire lock1")
    with lock1:  # 🔑 Same order as thread1
        print("Thread 2 acquired lock1")
        time.sleep(1)
        print("Thread 2 trying to acquire lock2")
        with lock2:
            print("Thread 2 acquired lock2")
            print("Thread 2 is doing work")
        print("Thread 2 released lock2")
    print("Thread 2 released lock1")

# Create and start threads
t1 = threading.Thread(target=thread1)
t2 = threading.Thread(target=thread2)

t1.start()
t2.start()

t1.join()
t2.join()

print("✅ Both threads finished without deadlock")
# Out:
# Thread 1 trying to acquire lock1
# Thread 1 acquired lock1
# Thread 2 trying to acquire lock1
# Thread 1 trying to acquire lock2
# Thread 1 acquired lock2
# Thread 1 is doing work
# Thread 1 released lock2
# Thread 1 released lock1
# Thread 2 acquired lock1
# Thread 2 trying to acquire lock2
# Thread 2 acquired lock2
# Thread 2 is doing work
# Thread 2 released lock2
# Thread 2 released lock1
# ✅ Both threads finished without deadlock

# %% [markdown]
# # ✅ 11. Producer–Consumer Problem (Inter-Thread Communication)
# # 🧠 Concept:
# - Producer: Generates data and adds to a shared queue.
# - Consumer: Takes data from the queue and processes it.
# - queue.Queue() is thread-safe, so no need for manual locking!

# %%
import threading
import time
import queue

q = queue.Queue()

def producer():
    for i in range(5):
        print(f"Producer: produced item {i}")
        q.put(i)
        time.sleep(1)
    q.put(None)  # Sentinel to stop consumer

def consumer():
    while True:
        item = q.get()
        if item is None:
            print("Consumer: received None, exiting.")
            break
        print(f"Consumer: consumed item {item}")
        time.sleep(1)

t1 = threading.Thread(target=producer)
t2 = threading.Thread(target=consumer)

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# Producer: produced item 0
# Consumer: consumed item 0
# Producer: produced item 1
# Consumer: consumed item 1
# Producer: produced item 2
# Consumer: consumed item 2
# Producer: produced item 3
# Consumer: consumed item 3
# Producer: produced item 4
# Consumer: consumed item 4
# Consumer: received None, exiting.
